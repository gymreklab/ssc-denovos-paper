# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# This notebook contains code to reproduce the following from Mitra, et al.:
#
# **Main Figures:**
# * Extended Data Figure 2E: Mutations of mutation rate

# %%
# Input per-locus info
LOCFILE = "/storage/mgymrek/ssc-denovos/denovos_GW_priors_Jan20/SSC_allphases_011720_denovos_GW_priors_Aug20.locus_stats_rmoutlierfams.tab"

# Make editable in Illustrator
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# Imports
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import scipy.stats
import statsmodels.discrete.discrete_model
import statsmodels.api as sm

# Other data paths
ANNOTFILE = "/storage/mgymrek/ssc-denovos/annotations/hg38_gangstr_MasterAnnotation-rmdup.bed"

# Color keys
colors = ['gray','red','gold','blue','green','purple','brown','salmon','magenta','cyan','darkblue']

# Output path info
OUTDIR = "pdfs/"

# %%
# Load per-locus mutation info
data = pd.read_csv(LOCFILE, delim_whitespace=True)

# Load annotation info
annot = pd.read_csv(ANNOTFILE, sep="\t")

# Set up fields
def GetChrom(x):
    if "chr" in str(x): return int(x[3:])
    else: return int(x)
data["chrom"] = data["chrom"].apply(GetChrom)
annot = annot[annot["chrom"].apply(lambda x: x not in ["X","chrX","Y","chrY"])]
annot["chrom"] = annot["chrom"].apply(GetChrom)
annot["pos"] = annot["start"]

# Merge
adata = pd.merge(data, annot, on=["chrom","pos"])

# %%
# Scale and remove outliers based on what we learned below
adata["RECOMB_RATE_LOG"] = np.log10(adata["RECOMB_RATE"]+0.0001)
adata = adata[adata["RECOMB_RATE_LOG"]>-3]

adata["AvgPhastCons_LOG"] = np.log10(adata["AvgPhastCons"]+0.0001)
adata = adata[adata["AvgPhastCons_LOG"]>-4]

adata = adata[adata["AvgNucOccMec"]>-1]
adata = adata[(adata["AvgNucOccDennis"]>-4) & (adata["AvgNucOccDennis"]<2)]

adata = adata[adata["QFEATURE-length"]<60]
# Explore each feature
for col in ['QFEATURE-length','RECOMB_RATE', 'RECOMB_RATE_LOG',
             'ESC_REP_TIME',
            'AvgPhastCons', "AvgPhastCons_LOG",
       'AvgNucOccMec',  'AvgNucOccDennis']:
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.hist(adata[~np.isnan(adata[col])][col], bins=25)
    ax.set_title(col)

# %%
# Fit model separately for each period

USECOLS = [# quantitative 
    "QFEATURE-length","QFEATURE-GCmotif","QFEATURE-GC50",
    "QFEATURE-GC100","QFEATURE-GC1000","QFEATURE-GC10000", 'RECOMB_RATE_LOG', 
     'ESC_REP_TIME', 'AvgPhastCons_LOG', 'AvgNucOccMec', 'AvgNucOccDennis',
    # binary
    "FEATURE-DNASE10","FEATURE-DNASE100","FEATURE-DNASE1000","FEATURE-DNASE10000",
    'FEATURE-H1_H3K27ac', 'FEATURE-H1_H3K4me1', 'FEATURE-H1_H3K4me3',
    'FEATURE-CONSPROMOTER'
          ]

def ZNorm(vals):
    m = np.mean(vals)
    sd = np.sqrt(np.var(vals))
    return [(item-m)/sd for item in vals]

coeffs_single = {}
coeffs_single_pvals = {}
coeffs_single_errs = {}
means = {} # period -> mean values

for period in range(1, 7):
    print("#### Period %s ######"%period)
    
    if period < 6:
        xdata = adata[adata["period"]==period].copy()
    else: xdata = adata[adata["period"]>= period].copy()
    print("period=%s, n=%s"%(period, xdata.shape[0]))
        
    # Get means
    means[period] = []
    for col in USECOLS:
        means[period].append(np.mean(xdata[col]))
        
    # Znorm all cols used
    for col in USECOLS:
        if len(set(xdata[col]))>1: # don't perform if all the same value
            xdata[col] = ZNorm(xdata[col])
    
    Y = np.array(xdata["mut_unaff"])
    T = np.array(xdata["all_unaff"])
    
    # Single models (but control for length)
    coeffs_single[period] = []
    coeffs_single_pvals[period] = []
    coeffs_single_errs[period] = []
    for col in USECOLS:
        if "length" in col:
            X = np.array(xdata[col])
            ind = 1
        else:
            if len(set(xdata[col]))==1:
                coeffs_single[period].extend([np.nan])
                coeffs_single_pvals[period].extend([np.nan])
                coeffs_single_errs[period].extend([np.nan])
                continue
            X = np.array(xdata[["QFEATURE-length",col]])
            ind = 2
        X = sm.add_constant(X)
        model = statsmodels.discrete.discrete_model.Poisson(Y, X, exposure=T)
        mfit = model.fit()
        
        
        coeffs_single[period].extend(mfit.params[ind:])
        coeffs_single_pvals[period].extend(mfit.pvalues[ind:])
        coeffs_single_errs[period].extend(np.sqrt(np.diag(mfit.cov_params())[ind:]))
# Out:
# #### Period 1 ######
# period=1, n=323955
# Optimization terminated successfully.
#          Current function value: 0.432202
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.428593
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.431922
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.431780
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.431980
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432187
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.431811
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432023
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432012
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.431967
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.431940
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432191
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432200
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432202
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432183
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432202
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432202
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432184
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432202
#          Iterations 7
# #### Period 2 ######
# period=2, n=91554
# Optimization terminated successfully.
#          Current function value: 0.446701
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.443207
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446686
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446598
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446414
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446521
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446680
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446620
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446701
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446623
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446551
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446700
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446700
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446699
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446701
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446701
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446694
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446556
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446700
#          Iterations 8
# #### Period 3 ######
# period=3, n=114350
# Optimization terminated successfully.
#          Current function value: 0.077807
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.076682
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.077806
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077739
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077744
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077771
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077751
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077804
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077762
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077738
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077795
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077551
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.077622
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077802
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077804
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077769
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077650
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.077803
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.077802
#          Iterations 29
# #### Period 4 ######
# period=4, n=279665
# Optimization terminated successfully.
#          Current function value: 0.074029
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.074018
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.073790
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.073893
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.074027
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.074026
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.074014
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.074029
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.074021
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.074002
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.074014
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.073946
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.073967
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.074027
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.074029
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.074009
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.073960
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.074028
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.074028
#          Iterations 29
# #### Period 5 ######
# period=5, n=113791
# Optimization terminated successfully.
#          Current function value: 0.041485
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041412
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041454
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041483
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041461
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041464
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041478
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041483
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041449
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041321
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041480
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041483
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041485
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041452
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041485
#          Iterations 33
# Optimization terminated successfully.
#          Current function value: 0.041466
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041444
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041476
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041483
#          Iterations 32
# #### Period 6 ######
# period=6, n=41354
# Optimization terminated successfully.
#          Current function value: 0.047598
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047569
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047348
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047268
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047372
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047532
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047570
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047597
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047562
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047200
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047390
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047569
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047507
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047587
#          Iterations 22
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.047549
#          Iterations: 35
# /storage/resources/source/anaconda2/envs/py37/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Optimization terminated successfully.
#          Current function value: 0.047598
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047516
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047397
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047594
#          Iterations 22

# %%
# Make single dataframe with results

periods = []
models = []
coeffs = []
pvals = []
cols = []
errs = []
meanvals = []

# for period in range(1, 7):
for period in range(1, 7):
    m = means[period]
    cs = coeffs_single[period]
    ps = coeffs_single_pvals[period]
    es = coeffs_single_errs[period]
    periods.extend([period]*len(cs))
    models.extend(["Single"]*len(cs))
    coeffs.extend(cs)
    pvals.extend(ps)
    errs.extend(es)
    cols.extend(USECOLS)
    meanvals.extend(m)
    
res = pd.DataFrame({"period": periods, "model": models,
                   "coeff": coeffs, "pval": pvals, "feature": cols,
                   "err": errs, "means": meanvals})
res["Z"] = res["coeff"]/res["err"]
res[res["period"]==2]
# Out:
#     period   model     coeff           pval               feature       err  \
# 19       2  Single  1.089617   0.000000e+00       QFEATURE-length  0.005991
# 20       2  Single -0.285680  5.970794e-158      QFEATURE-GCmotif  0.010669
# 21       2  Single  0.012768   9.823200e-02         QFEATURE-GC50  0.007722
# 22       2  Single  0.032873   1.278002e-05        QFEATURE-GC100  0.007533
# 23       2  Single  0.051057   2.841368e-13       QFEATURE-GC1000  0.006992
# 24       2  Single  0.040145   7.565025e-09      QFEATURE-GC10000  0.006948
# 25       2  Single  0.013594   5.076042e-02       RECOMB_RATE_LOG  0.006959
# 26       2  Single  0.027367   1.196919e-04          ESC_REP_TIME  0.007114
# 27       2  Single  0.001758   8.053677e-01      AvgPhastCons_LOG  0.007136
# 28       2  Single -0.029674   1.482026e-04          AvgNucOccMec  0.007821
# 29       2  Single  0.038527   1.439446e-07       AvgNucOccDennis  0.007324
# 30       2  Single -0.002205   7.323122e-01       FEATURE-DNASE10  0.006446
# 31       2  Single  0.002985   6.566269e-01      FEATURE-DNASE100  0.006715
# 32       2  Single  0.004532   5.363980e-01     FEATURE-DNASE1000  0.007330
# 33       2  Single  0.000326   9.657788e-01    FEATURE-DNASE10000  0.007597
# 34       2  Single  0.000506   9.429700e-01    FEATURE-H1_H3K27ac  0.007077
# 35       2  Single  0.006989   2.635695e-01    FEATURE-H1_H3K4me1  0.006252
# 36       2  Single  0.032642   1.010236e-07    FEATURE-H1_H3K4me3  0.006130
# 37       2  Single -0.002581   6.453866e-01  FEATURE-CONSPROMOTER  0.005609
#
#         means           Z
# 19  20.321384  181.889392
# 20   0.398333  -26.777111
# 21   0.380867    1.653486
# 22   0.386606    4.363838
# 23   0.399127    7.301708
# 24   0.403845    5.777874
# 25  -0.658483    1.953500
# 26  -0.067239    3.846756
# 27  -1.290255    0.246406
# 28   0.814643   -3.794062
# 29  -1.404479    5.260141
# 30   0.192018   -0.342051
# 31   0.300478    0.444575
# 32   0.731754    0.618269
# 33   0.997171    0.042903
# 34   0.016580    0.071537
# 35   0.056054    1.117994
# 36   0.022599    5.324873
# 37   0.006575   -0.460181

# %%
for period in range(1, 5):
    print(res[(res["period"]==4) & (res["feature"]!="ESC_REP_TIME")]["pval"].apply(lambda x: "%.2g"%x))
# Out:
# 57          0
# 58      0.013
# 59    7.6e-31
# 60    2.7e-18
# 61       0.36
# 62       0.22
# 63     0.0042
# 65      0.034
# 66    0.00012
# 67     0.0036
# 68    6.1e-11
# 69      7e-09
# 70       0.33
# 71       0.99
# 72      0.003
# 73    2.6e-08
# 74       0.47
# 75        0.4
# Name: pval, dtype: object
# 57          0
# 58      0.013
# 59    7.6e-31
# 60    2.7e-18
# 61       0.36
# 62       0.22
# 63     0.0042
# 65      0.034
# 66    0.00012
# 67     0.0036
# 68    6.1e-11
# 69      7e-09
# 70       0.33
# 71       0.99
# 72      0.003
# 73    2.6e-08
# 74       0.47
# 75        0.4
# Name: pval, dtype: object
# 57          0
# 58      0.013
# 59    7.6e-31
# 60    2.7e-18
# 61       0.36
# 62       0.22
# 63     0.0042
# 65      0.034
# 66    0.00012
# 67     0.0036
# 68    6.1e-11
# 69      7e-09
# 70       0.33
# 71       0.99
# 72      0.003
# 73    2.6e-08
# 74       0.47
# 75        0.4
# Name: pval, dtype: object
# 57          0
# 58      0.013
# 59    7.6e-31
# 60    2.7e-18
# 61       0.36
# 62       0.22
# 63     0.0042
# 65      0.034
# 66    0.00012
# 67     0.0036
# 68    6.1e-11
# 69      7e-09
# 70       0.33
# 71       0.99
# 72      0.003
# 73    2.6e-08
# 74       0.47
# 75        0.4
# Name: pval, dtype: object

# %%
# Mult hypothesis threshold
0.01/(4*18)
# Out:
# 0.0001388888888888889

# %%
catcols = []
for col in USECOLS:
    if "length" in col:
        catcols.append("black")
    elif "GC" in col:
        catcols.append("darkblue")
    elif "DNASE" in col:
        catcols.append("darkred")
    elif "ChromHMM" in col:
        catcols.append("darkcyan")
    elif "H1" in col:
        catcols.append("violet")
    elif "TIME" in col:
        catcols.append("coral")
    elif "Avg" in col:
        catcols.append("darkgreen")
    else:
        catcols.append("gray")
        
for period in range(1, 5):
    r = res[(res["period"]==period) & (res["model"]=="Single")]
    fig = plt.figure()
    fig.set_size_inches((10, 2))
    ax = fig.add_subplot(111)
    ax.bar(range(r.shape[0]), r["coeff"], yerr=r["err"]*1.96, color=catcols)
    ax.set_xticks(range(r.shape[0]))
    ax.set_xticklabels(r["feature"].apply(lambda x: x.split("-")[1] if "-" in x else x))
    #ax.set_title("Period=%s"%period)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    #ax.set_ylim(bottom=-0.5, top=1.2)
    # Hide the right and top spines
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.yaxis.set_ticks_position('left')
    ax.xaxis.set_ticks_position('bottom');
    #ax.set_xticklabels([])
    fig.savefig(os.path.join(OUTDIR,"Figure2_MutationDeterminants_period%s.pdf"%period))
