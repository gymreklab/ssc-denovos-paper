# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# This notebook contains code to reproduce the following from Mitra, et al.:
#
# **Main Figures:**
# * Figure 2D: Mutations of mutation rate

# %%
# Input per-locus info
LOCFILE = "/storage/ileena/ssc-gangstr-denovos/denovos_GW_priors_Jan20/combined/SSC_allphases_011720_denovos_GW_priors_Jan20.locus_stats.tab"

# Make editable in Illustrator
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# Imports
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import scipy.stats
import statsmodels.discrete.discrete_model
import statsmodels.api as sm

# Other data paths
ANNOTFILE = "/storage/mgymrek/ssc-denovos/annotations/hg38_gangstr_MasterAnnotation-rmdup.bed"

# Color keys
colors = ['gray','red','gold','blue','green','purple','brown','salmon','magenta','cyan','darkblue']

# Output path info
OUTDIR = "pdfs/"

# %%
# Load per-locus mutation info
data = pd.read_csv(LOCFILE, delim_whitespace=True)

# Load annotation info
annot = pd.read_csv(ANNOTFILE, sep="\t")

# Set up fields
def GetChrom(x):
    if "chr" in str(x): return int(x[3:])
    else: return int(x)
data["chrom"] = data["chrom"].apply(GetChrom)
annot = annot[annot["chrom"].apply(lambda x: x not in ["X","chrX","Y","chrY"])]
annot["chrom"] = annot["chrom"].apply(GetChrom)
annot["pos"] = annot["start"]

# Merge
adata = pd.merge(data, annot, on=["chrom","pos"])

# %%
# Scale and remove outliers based on what we learned below
adata["RECOMB_RATE_LOG"] = np.log10(adata["RECOMB_RATE"]+0.0001)
adata = adata[adata["RECOMB_RATE_LOG"]>-3]

adata["AvgPhastCons_LOG"] = np.log10(adata["AvgPhastCons"]+0.0001)
adata = adata[adata["AvgPhastCons_LOG"]>-4]

adata = adata[adata["AvgNucOccMec"]>-1]
adata = adata[(adata["AvgNucOccDennis"]>-4) & (adata["AvgNucOccDennis"]<2)]

adata = adata[adata["QFEATURE-length"]<60]
# Explore each feature
for col in ['QFEATURE-length','RECOMB_RATE', 'RECOMB_RATE_LOG',
             'ESC_REP_TIME',
            'AvgPhastCons', "AvgPhastCons_LOG",
       'AvgNucOccMec',  'AvgNucOccDennis']:
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.hist(adata[~np.isnan(adata[col])][col], bins=25)
    ax.set_title(col)

# %%
# Fit model separately for each period

USECOLS = [# quantitative 
    "QFEATURE-length","QFEATURE-GCmotif","QFEATURE-GC50",
    "QFEATURE-GC100","QFEATURE-GC1000","QFEATURE-GC10000", 'RECOMB_RATE_LOG', 
     'ESC_REP_TIME', 'AvgPhastCons_LOG', 'AvgNucOccMec', 'AvgNucOccDennis',
    # binary
    "FEATURE-DNASE10","FEATURE-DNASE100","FEATURE-DNASE1000","FEATURE-DNASE10000",
    'FEATURE-H1_H3K27ac', 'FEATURE-H1_H3K4me1', 'FEATURE-H1_H3K4me3',
    'FEATURE-CONSPROMOTER'
          ]

def ZNorm(vals):
    m = np.mean(vals)
    sd = np.sqrt(np.var(vals))
    return [(item-m)/sd for item in vals]

coeffs_single = {}
coeffs_single_pvals = {}
coeffs_single_errs = {}
means = {} # period -> mean values

for period in range(1, 7):
    print("#### Period %s ######"%period)
    
    if period < 6:
        xdata = adata[adata["period"]==period].copy()
    else: xdata = adata[adata["period"]>= period].copy()
        
    # Get means
    means[period] = []
    for col in USECOLS:
        means[period].append(np.mean(xdata[col]))
        
    # Znorm all cols used
    for col in USECOLS:
        if len(set(xdata[col]))>1: # don't perform if all the same value
            xdata[col] = ZNorm(xdata[col])
    
    Y = np.array(xdata["mut_unaff"])
    T = np.array(xdata["all_unaff"])
    
    # Single models (but control for length)
    coeffs_single[period] = []
    coeffs_single_pvals[period] = []
    coeffs_single_errs[period] = []
    for col in USECOLS:
        if "length" in col:
            X = np.array(xdata[col])
            ind = 1
        else:
            if len(set(xdata[col]))==1:
                coeffs_single[period].extend([np.nan])
                coeffs_single_pvals[period].extend([np.nan])
                coeffs_single_errs[period].extend([np.nan])
                continue
            X = np.array(xdata[["QFEATURE-length",col]])
            ind = 2
        X = sm.add_constant(X)
        model = statsmodels.discrete.discrete_model.Poisson(Y, X, exposure=T)
        mfit = model.fit()
        
        
        coeffs_single[period].extend(mfit.params[ind:])
        coeffs_single_pvals[period].extend(mfit.pvalues[ind:])
        coeffs_single_errs[period].extend(np.sqrt(np.diag(mfit.cov_params())[ind:]))
# Out:
# #### Period 1 ######
# Optimization terminated successfully.
#          Current function value: 0.432565
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.428949
#          Iterations 9
# Optimization terminated successfully.
#          Current function value: 0.432283
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432140
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432343
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432550
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432173
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432386
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432374
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432329
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432304
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432554
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432562
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432565
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432546
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432565
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432565
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432547
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.432564
#          Iterations 7
# #### Period 2 ######
# Optimization terminated successfully.
#          Current function value: 0.447062
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.443544
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.447048
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446959
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446777
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446884
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.447041
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446982
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.447062
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446986
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446913
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.447061
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.447061
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.447060
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.447062
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.447062
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.447056
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.446919
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.447061
#          Iterations 8
# #### Period 3 ######
# Optimization terminated successfully.
#          Current function value: 0.077807
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.076682
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.077806
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077739
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077745
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077772
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077751
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077804
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077762
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077738
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077795
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077551
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.077622
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077802
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077804
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077769
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.077650
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.077803
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.077802
#          Iterations 29
# #### Period 4 ######
# Optimization terminated successfully.
#          Current function value: 0.074080
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.074069
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.073842
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.073945
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.074079
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.074077
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.074066
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.074080
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.074072
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.074053
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.074065
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.073996
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.074017
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.074078
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.074080
#          Iterations 30
# Optimization terminated successfully.
#          Current function value: 0.074060
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.074013
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.074079
#          Iterations 29
# Optimization terminated successfully.
#          Current function value: 0.074079
#          Iterations 29
# #### Period 5 ######
# Optimization terminated successfully.
#          Current function value: 0.041547
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041473
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041514
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041545
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041522
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041525
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041539
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041544
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041509
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041381
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041541
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041544
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041546
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041514
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041546
#          Iterations 33
# Optimization terminated successfully.
#          Current function value: 0.041527
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041504
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041538
#          Iterations 32
# Optimization terminated successfully.
#          Current function value: 0.041545
#          Iterations 32
# #### Period 6 ######
# Optimization terminated successfully.
#          Current function value: 0.047599
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047571
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047349
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047270
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047373
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047534
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047572
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047598
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047563
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047202
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047392
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047571
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047508
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047589
#          Iterations 22
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.047551
#          Iterations: 35
# /storage/resources/source/anaconda2/envs/py37/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Optimization terminated successfully.
#          Current function value: 0.047599
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047518
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047399
#          Iterations 22
# Optimization terminated successfully.
#          Current function value: 0.047595
#          Iterations 22

# %%
# Make single dataframe with results

periods = []
models = []
coeffs = []
pvals = []
cols = []
errs = []
meanvals = []

# for period in range(1, 7):
for period in range(1, 7):
    m = means[period]
    cs = coeffs_single[period]
    ps = coeffs_single_pvals[period]
    es = coeffs_single_errs[period]
    periods.extend([period]*len(cs))
    models.extend(["Single"]*len(cs))
    coeffs.extend(cs)
    pvals.extend(ps)
    errs.extend(es)
    cols.extend(USECOLS)
    meanvals.extend(m)
    
res = pd.DataFrame({"period": periods, "model": models,
                   "coeff": coeffs, "pval": pvals, "feature": cols,
                   "err": errs, "means": meanvals})
res["Z"] = res["coeff"]/res["err"]
res[res["period"]==2]
# Out:
#     period   model     coeff           pval               feature       err  \
# 19       2  Single  1.089597   0.000000e+00       QFEATURE-length  0.005987
# 20       2  Single -0.286397  4.797912e-159      QFEATURE-GCmotif  0.010658
# 21       2  Single  0.012427   1.073623e-01         QFEATURE-GC50  0.007718
# 22       2  Single  0.032735   1.373872e-05        QFEATURE-GC100  0.007529
# 23       2  Single  0.050780   3.712659e-13       QFEATURE-GC1000  0.006989
# 24       2  Single  0.039868   9.430052e-09      QFEATURE-GC10000  0.006945
# 25       2  Single  0.013502   5.219989e-02       RECOMB_RATE_LOG  0.006955
# 26       2  Single  0.027225   1.284843e-04          ESC_REP_TIME  0.007110
# 27       2  Single  0.002056   7.731442e-01      AvgPhastCons_LOG  0.007132
# 28       2  Single -0.029331   1.755260e-04          AvgNucOccMec  0.007818
# 29       2  Single  0.038362   1.602254e-07       AvgNucOccDennis  0.007320
# 30       2  Single -0.002313   7.195990e-01       FEATURE-DNASE10  0.006443
# 31       2  Single  0.002794   6.771248e-01      FEATURE-DNASE100  0.006711
# 32       2  Single  0.004099   5.757054e-01     FEATURE-DNASE1000  0.007324
# 33       2  Single  0.000380   9.600684e-01    FEATURE-DNASE10000  0.007597
# 34       2  Single  0.000344   9.612235e-01    FEATURE-H1_H3K27ac  0.007076
# 35       2  Single  0.006685   2.848869e-01    FEATURE-H1_H3K4me1  0.006251
# 36       2  Single  0.032458   1.190168e-07    FEATURE-H1_H3K4me3  0.006130
# 37       2  Single -0.002686   6.320818e-01  FEATURE-CONSPROMOTER  0.005609
#
#         means           Z
# 19  20.321384  181.994761
# 20   0.398333  -26.870974
# 21   0.380867    1.610163
# 22   0.386606    4.347996
# 23   0.399127    7.265644
# 24   0.403845    5.740674
# 25  -0.658483    1.941482
# 26  -0.067239    3.829346
# 27  -1.290255    0.288265
# 28   0.814643   -3.751862
# 29  -1.404479    5.240404
# 30   0.192018   -0.358995
# 31   0.300478    0.416390
# 32   0.731754    0.559669
# 33   0.997171    0.050068
# 34   0.016580    0.048618
# 35   0.056054    1.069406
# 36   0.022599    5.294999
# 37   0.006575   -0.478799

# %%
catcols = []
for col in USECOLS:
    if "length" in col:
        catcols.append("black")
    elif "GC" in col:
        catcols.append("darkblue")
    elif "DNASE" in col:
        catcols.append("darkred")
    elif "ChromHMM" in col:
        catcols.append("darkcyan")
    elif "H1" in col:
        catcols.append("violet")
    elif "TIME" in col:
        catcols.append("coral")
    elif "Avg" in col:
        catcols.append("darkgreen")
    else:
        catcols.append("gray")
        
for period in range(1, 5):
    r = res[(res["period"]==period) & (res["model"]=="Single")]
    fig = plt.figure()
    fig.set_size_inches((10, 2))
    ax = fig.add_subplot(111)
    ax.bar(range(r.shape[0]), r["coeff"], yerr=r["err"]*1.96, color=catcols)
    ax.set_xticks(range(r.shape[0]))
    ax.set_xticklabels(r["feature"].apply(lambda x: x.split("-")[1] if "-" in x else x))
    #ax.set_title("Period=%s"%period)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    #ax.set_ylim(bottom=-0.5, top=1.2)
    # Hide the right and top spines
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.yaxis.set_ticks_position('left')
    ax.xaxis.set_ticks_position('bottom');
    #ax.set_xticklabels([])
    fig.savefig(os.path.join(OUTDIR,"Figure2_MutationDeterminants_period%s.pdf"%period))
